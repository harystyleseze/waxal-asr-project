# %%
import sys
print(sys.executable)
# Out:
# /workspace/waxal-asr-project/.venv/bin/python

# %%
import os
import pandas as pd
import numpy as np

from datasets import load_dataset

import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.auto import tqdm

# %%
dataset = load_dataset(
    "google/WaxalNLP"
)

dataset
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/29.2k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/72 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataset = load_dataset(
#       2     "google/WaxalNLP"
#       3 )
#       5 dataset
#
# File /workspace/waxal-asr-project/.venv/lib/python3.10/site-packages/datasets/load.py:1698, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1693 verification_mode = VerificationMode(
#    1694     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1695 )
#    1697 # Create a dataset builder
# -> 1698 builder_instance = load_dataset_builder(
#    1699     path=path,
#    1700     name=name,
#    1701     data_dir=data_dir,
#    1702     data_files=data_files,
#    1703     cache_dir=cache_dir,
#    1704     features=features,
#    1705     download_config=download_config,
#    1706     download_mode=download_mode,
#    1707     revision=revision,
#    1708     token=token,
#    1709     storage_options=storage_options,
#    1710     **config_kwargs,
#    1711 )
#    1713 # Return iterable dataset in case of streaming
#    1714 if streaming:
#
# File /workspace/waxal-asr-project/.venv/lib/python3.10/site-packages/datasets/load.py:1363, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1361 builder_cls = get_dataset_builder_class(dataset_module, dataset_name=dataset_name)
#    1362 # Instantiate the dataset builder
# -> 1363 builder_instance: DatasetBuilder = builder_cls(
#    1364     cache_dir=cache_dir,
#    1365     dataset_name=dataset_name,
#    1366     config_name=config_name,
#    1367     data_dir=data_dir,
#    1368     data_files=data_files,
#    1369     hash=dataset_module.hash,
#    1370     info=info,
#    1371     features=features,
#    1372     token=token,
#    1373     storage_options=storage_options,
#    1374     **builder_kwargs,
#    1375     **config_kwargs,
#    1376 )
#    1377 builder_instance._use_legacy_cache_dir_if_possible(dataset_module)
#    1379 return builder_instance
#
# File /workspace/waxal-asr-project/.venv/lib/python3.10/site-packages/datasets/builder.py:351, in DatasetBuilder.__init__(self, cache_dir, dataset_name, config_name, hash, base_path, info, features, token, repo_id, data_files, data_dir, storage_options, writer_batch_size, config_id, **config_kwargs)
#     349     config_kwargs["data_dir"] = data_dir
#     350 self.config_kwargs = config_kwargs
# --> 351 self.config, self.config_id = self._create_builder_config(
#     352     config_name=config_name,
#     353     custom_features=features,
#     354     config_id=config_id,
#     355     **config_kwargs,
#     356 )
#     358 # prepare info: DatasetInfo are a standardized dataclass across all datasets
#     359 # Prefill datasetinfo
#     360 if info is None:
#
# File /workspace/waxal-asr-project/.venv/lib/python3.10/site-packages/datasets/builder.py:523, in DatasetBuilder._create_builder_config(self, config_name, custom_features, config_id, **config_kwargs)
#     519     if not config_kwargs:
#     520         example_of_usage = (
#     521             f"load_dataset('{self.repo_id or self.dataset_name}', '{self.BUILDER_CONFIGS[0].name}')"
#     522         )
# --> 523         raise ValueError(
#     524             "Config name is missing."
#     525             f"\nPlease pick one among the available configs: {list(self.builder_configs.keys())}"
#     526             + f"\nExample of usage:\n\t`{example_of_usage}`"
#     527         )
#     528 else:
#     529     builder_config = self.BUILDER_CONFIGS[0]
#
# ValueError: Config name is missing.
# Please pick one among the available configs: ['ach_asr', 'ach_tts', 'aka_asr', 'amh_asr', 'bau_tts', 'dag_asr', 'dga_asr', 'ewe_asr', 'ewe_tts', 'fat_tts', 'ful_asr', 'ful_tts', 'hau_tts', 'ibo_tts', 'kik_tts', 'kpo_asr', 'lin_asr', 'lug_asr', 'lug_tts', 'luo_tts', 'mas_asr', 'mlg_asr', 'nyn_asr', 'nyn_tts', 'orm_asr', 'pcm_tts', 'sid_asr', 'sna_asr', 'tir_asr', 'sog_asr', 'swa_tts', 'twi_tts', 'yor_tts', 'wal_asr']
# Example of usage:
# 	`load_dataset('google/WaxalNLP', 'ach_asr')`

# %%
from datasets import get_dataset_config_names

configs = get_dataset_config_names("google/WaxalNLP")
configs
# Out:
# Resolving data files:   0%|          | 0/72 [00:00<?, ?it/s]
# ['ach_asr',
#  'ach_tts',
#  'aka_asr',
#  'amh_asr',
#  'bau_tts',
#  'dag_asr',
#  'dga_asr',
#  'ewe_asr',
#  'ewe_tts',
#  'fat_tts',
#  'ful_asr',
#  'ful_tts',
#  'hau_tts',
#  'ibo_tts',
#  'kik_tts',
#  'kpo_asr',
#  'lin_asr',
#  'lug_asr',
#  'lug_tts',
#  'luo_tts',
#  'mas_asr',
#  'mlg_asr',
#  'nyn_asr',
#  'nyn_tts',
#  'orm_asr',
#  'pcm_tts',
#  'sid_asr',
#  'sna_asr',
#  'tir_asr',
#  'sog_asr',
#  'swa_tts',
#  'twi_tts',
#  'yor_tts',
#  'wal_asr']

# %%
from datasets import load_dataset

nigerian = load_dataset(
    "benjaminogbonna/nigerian_common_voice_dataset"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/13.3k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from datasets import load_dataset
# ----> 3 nigerian = load_dataset(
#       4     "benjaminogbonna/nigerian_common_voice_dataset"
#       5 )
#
# File /workspace/waxal-asr-project/.venv/lib/python3.10/site-packages/datasets/load.py:1698, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1693 verification_mode = VerificationMode(
#    1694     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1695 )
#    1697 # Create a dataset builder
# -> 1698 builder_instance = load_dataset_builder(
#    1699     path=path,
#    1700     name=name,
#    1701     data_dir=data_dir,
#    1702     data_files=data_files,
#    1703     cache_dir=cache_dir,
#    1704     features=features,
#    1705     download_config=download_config,
#    1706     download_mode=download_mode,
#    1707     revision=revision,
#    1708     token=token,
#    1709     storage_options=storage_options,
#    1710     **config_kwargs,
#    1711 )
#    1713 # Return iterable dataset in case of streaming
#    1714 if streaming:
#
# File /workspace/waxal-asr-project/.venv/lib/python3.10/site-packages/datasets/load.py:1363, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1361 builder_cls = get_dataset_builder_class(dataset_module, dataset_name=dataset_name)
#    1362 # Instantiate the dataset builder
# -> 1363 builder_instance: DatasetBuilder = builder_cls(
#    1364     cache_dir=cache_dir,
#    1365     dataset_name=dataset_name,
#    1366     config_name=config_name,
#    1367     data_dir=data_dir,
#    1368     data_files=data_files,
#    1369     hash=dataset_module.hash,
#    1370     info=info,
#    1371     features=features,
#    1372     token=token,
#    1373     storage_options=storage_options,
#    1374     **builder_kwargs,
#    1375     **config_kwargs,
#    1376 )
#    1377 builder_instance._use_legacy_cache_dir_if_possible(dataset_module)
#    1379 return builder_instance
#
# File /workspace/waxal-asr-project/.venv/lib/python3.10/site-packages/datasets/builder.py:351, in DatasetBuilder.__init__(self, cache_dir, dataset_name, config_name, hash, base_path, info, features, token, repo_id, data_files, data_dir, storage_options, writer_batch_size, config_id, **config_kwargs)
#     349     config_kwargs["data_dir"] = data_dir
#     350 self.config_kwargs = config_kwargs
# --> 351 self.config, self.config_id = self._create_builder_config(
#     352     config_name=config_name,
#     353     custom_features=features,
#     354     config_id=config_id,
#     355     **config_kwargs,
#     356 )
#     358 # prepare info: DatasetInfo are a standardized dataclass across all datasets
#     359 # Prefill datasetinfo
#     360 if info is None:
#
# File /workspace/waxal-asr-project/.venv/lib/python3.10/site-packages/datasets/builder.py:523, in DatasetBuilder._create_builder_config(self, config_name, custom_features, config_id, **config_kwargs)
#     519     if not config_kwargs:
#     520         example_of_usage = (
#     521             f"load_dataset('{self.repo_id or self.dataset_name}', '{self.BUILDER_CONFIGS[0].name}')"
#     522         )
# --> 523         raise ValueError(
#     524             "Config name is missing."
#     525             f"\nPlease pick one among the available configs: {list(self.builder_configs.keys())}"
#     526             + f"\nExample of usage:\n\t`{example_of_usage}`"
#     527         )
#     528 else:
#     529     builder_config = self.BUILDER_CONFIGS[0]
#
# ValueError: Config name is missing.
# Please pick one among the available configs: ['english', 'hausa', 'igbo', 'yoruba']
# Example of usage:
# 	`load_dataset('benjaminogbonna/nigerian_common_voice_dataset', 'english')`

# %%
hausa = load_dataset(
    "benjaminogbonna/nigerian_common_voice_dataset",
    "hausa"
)

# %%
igbo = load_dataset(
    "benjaminogbonna/nigerian_common_voice_dataset",
    "igbo"
)

# %%
yoruba = load_dataset(
    "benjaminogbonna/nigerian_common_voice_dataset",
    "yoruba"
)

# %%
from datasets import load_dataset

fulfulde = load_dataset(
    "google/WaxalNLP",
    "ful_asr"
)

yoruba_related = load_dataset(
    "google/WaxalNLP",
    "aka_asr"
)
